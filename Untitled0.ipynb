# %% [markdown]
# <a href="https://colab.research.google.com/github/VedangJotaniya/CP441_Project_Repo/blob/gh-pages/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Making the ideated model that consists convolutional and then LSTM.
# For convolutional model, using RESNET50 and freezing its all layers and making fully connected last layer, which will be input to the LSTM

# %% [markdown]
# First importing libraries neccesary for RESNET50

# %%
from keras.applications.resnet50 import ResNet50
from keras.models import Model
import keras

# %% [markdown]
# COde for model instantiation

# %%
IMG_HEIGHT=IMG_WIDTH=300


restnet = ResNet50(include_top=False, weights='imagenet', input_shape=(IMG_HEIGHT,IMG_WIDTH,3))


output = restnet.layers[-1].output
output = keras.layers.Flatten()(output)
print(output)

restnet = Model(inputs=restnet.input, outputs=output)

for layer in restnet.layers:
    layer.trainable = False


restnet.summary()
# Out:
# Tensor("flatten_12/Reshape:0", shape=(None, 204800), dtype=float32)
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_21 (InputLayer)           [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 306, 306, 3)  0           input_21[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 150, 150, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 150, 150, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# ...

# %% [markdown]
# NOW importing libraries for next sequence LSTM network

# %%
import numpy as np
#np.random.seed(0)
import tensorflow as tf
from keras.models import Model, Sequential
from keras.layers import Dense, Input, Dropout, LSTM, Activation, Lambda
from keras.layers.embeddings import Embedding
from keras.preprocessing import sequence
from keras.initializers import glorot_uniform
#np.random.seed(1)

# %% [markdown]
# NOW code for joining resnet with LSTM

# %%
model = Sequential()

model.add(restnet)

model.add(Lambda(lambda x: tf.expand_dims(model.output, axis=-1)))
model.add(LSTM(128,return_sequences=True))
model.add(Dropout(0.5))
model.add(LSTM(units = 128, return_sequences=False))
model.add(Dropout(0.5))
model.add(Dense(3, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# functional_7 (Functional)    (None, 204800)            23587712
# _________________________________________________________________
# lambda_3 (Lambda)            (None, 204800, 1)         0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 204800, 128)       66560
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 204800, 128)       0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 128)               131584
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 387
# ...
